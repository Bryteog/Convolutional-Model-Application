# %%
import math
import numpy as np
import pandas as pd
import h5py
import scipy
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import tensorflow as tf
from tensorflow import  keras
from tensorflow.keras import layers
from tensorflow.python.framework import ops
from Constants_utils import *
# %matplotlib inline
# Out:
# c:\Users\dell\miniconda3\envs\tf_cpu\Lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.12.2 when it was built against 1.12.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
X_train, y_train, X_test, y_test, classes = load_happy_dataset()

# %%
idx = 121
plt.imshow(X_train[idx])
plt.show()

# %%
X_train = X_train / 255.
X_test = X_test / 255.

y_train = y_train.T
y_test = y_test.T

print("Number of training samples: ", X_train.shape[0])
print("Number of test samples: ", X_test.shape[0])
print("X_train set shape: ", X_train.shape)
print("X_test set shape: ", X_test.shape)
print("y_train set shape:", y_train.shape)
print("y_test set shape: ", y_test.shape)
# Out:
# Number of training samples:  600
# Number of test samples:  150
# X_train set shape:  (600, 64, 64, 3)
# X_test set shape:  (150, 64, 64, 3)
# y_train set shape: (600, 1)
# y_test set shape:  (150, 1)

# %%
def happy_model(input_shape):
    
    model = keras.Sequential([
        layers.ZeroPadding2D(padding = (3, 3),input_shape = (64, 64, 3), data_format = "channels_last"),
        layers.Conv2D(64, (7, 7), strides = (1, 1), activation = 'relu'),
        layers.BatchNormalization(),
        layers.ReLU(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),
        layers.Flatten(),
        layers.Dense(32, activation = 'relu'),
        layers.Dropout(0.25),
        layers.Dense(1, activation = 'sigmoid'),
    ])
    
    return model

# %%
happy_model = happy_model((64, 64, 3))
#happy_model.summary()

# %%
happy_model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# %%
history = happy_model.fit(X_train, y_train,
                batch_size = 64,
                validation_data = (X_test, y_test),
                epochs = 100,
                verbose = 2
                )
# Out:
# Epoch 1/100
# 10/10 - 10s - loss: 3.1854 - accuracy: 0.5383 - val_loss: 0.6924 - val_accuracy: 0.5200 - 10s/epoch - 1s/step
# Epoch 2/100
# 10/10 - 7s - loss: 0.6236 - accuracy: 0.7100 - val_loss: 0.6961 - val_accuracy: 0.5600 - 7s/epoch - 713ms/step
# Epoch 3/100
# 10/10 - 7s - loss: 0.5721 - accuracy: 0.7533 - val_loss: 0.6713 - val_accuracy: 0.5333 - 7s/epoch - 666ms/step
# Epoch 4/100
# 10/10 - 8s - loss: 0.4461 - accuracy: 0.7983 - val_loss: 0.6565 - val_accuracy: 0.5800 - 8s/epoch - 825ms/step
# Epoch 5/100
# 10/10 - 7s - loss: 0.3978 - accuracy: 0.8067 - val_loss: 0.6399 - val_accuracy: 0.5733 - 7s/epoch - 738ms/step
# Epoch 6/100
# 10/10 - 8s - loss: 0.3479 - accuracy: 0.8233 - val_loss: 0.6184 - val_accuracy: 0.6000 - 8s/epoch - 755ms/step
# Epoch 7/100
# 10/10 - 7s - loss: 0.3191 - accuracy: 0.8217 - val_loss: 0.5941 - val_accuracy: 0.6867 - 7s/epoch - 680ms/step
# Epoch 8/100
# 10/10 - 7s - loss: 0.3106 - accuracy: 0.8133 - val_loss: 0.5785 - val_accuracy: 0.7067 - 7s/epoch - 702ms/step
# Epoch 9/100
# 10/10 - 6s - loss: 0.2646 - accuracy: 0.8533 - val_loss: 0.5555 - val_accuracy: 0.6933 - 6s/epoch - 640ms/step
# Epoch 10/100
# 10/10 - 7s - loss: 0.2500 - accuracy: 0.8567 - val_loss: 0.5571 - val_accuracy: 0.6800 - 7s/epoch - 738ms/step
# Epoch 11/100
# 10/10 - 6s - loss: 0.2988 - accuracy: 0.8317 - val_loss: 0.5608 - val_accuracy: 0.7333 - 6s/epoch - 618ms/step
# Epoch 12/100
# 10/10 - 6s - loss: 0.2584 - accuracy: 0.8417 - val_loss: 0.5204 - val_accuracy: 0.7733 - 6s/epoch - 643ms/step
# Epoch 13/100
# 10/10 - 7s - loss: 0.2475 - accuracy: 0.8517 - val_loss: 0.5135 - val_accuracy: 0.7800 - 7s/epoch - 667ms/step
# Epoch 14/100
# 10/10 - 6s - loss: 0.2321 - accuracy: 0.8583 - val_loss: 0.4806 - val_accuracy: 0.8933 - 6s/epoch - 611ms/step
# Epoch 15/100
# 10/10 - 7s - loss: 0.2342 - accuracy: 0.8933 - val_loss: 0.4607 - val_accuracy: 0.8400 - 7s/epoch - 670ms/step
# Epoch 16/100
# 10/10 - 7s - loss: 0.1841 - accuracy: 0.8933 - val_loss: 0.4334 - val_accuracy: 0.8867 - 7s/epoch - 676ms/step
# Epoch 17/100
# 10/10 - 6s - loss: 0.1775 - accuracy: 0.9017 - val_loss: 0.3886 - val_accuracy: 0.9067 - 6s/epoch - 647ms/step
# Epoch 18/100
# 10/10 - 6s - loss: 0.1480 - accuracy: 0.9200 - val_loss: 0.3873 - val_accuracy: 0.9067 - 6s/epoch - 615ms/step
# Epoch 19/100
# 10/10 - 6s - loss: 0.1338 - accuracy: 0.9317 - val_loss: 0.3751 - val_accuracy: 0.9133 - 6s/epoch - 616ms/step
# Epoch 20/100
# 10/10 - 6s - loss: 0.1234 - accuracy: 0.9283 - val_loss: 0.3832 - val_accuracy: 0.9200 - 6s/epoch - 644ms/step
# Epoch 21/100
# 10/10 - 7s - loss: 0.1256 - accuracy: 0.9267 - val_loss: 0.3609 - val_accuracy: 0.8667 - 7s/epoch - 665ms/step
# Epoch 22/100
# 10/10 - 7s - loss: 0.1238 - accuracy: 0.9283 - val_loss: 0.3643 - val_accuracy: 0.9333 - 7s/epoch - 684ms/step
# Epoch 23/100
# 10/10 - 8s - loss: 0.1145 - accuracy: 0.9283 - val_loss: 0.3120 - val_accuracy: 0.8800 - 8s/epoch - 776ms/step
# Epoch 24/100
# 10/10 - 7s - loss: 0.1171 - accuracy: 0.9300 - val_loss: 0.3294 - val_accuracy: 0.9400 - 7s/epoch - 683ms/step
# Epoch 25/100
# 10/10 - 6s - loss: 0.1303 - accuracy: 0.9200 - val_loss: 0.3191 - val_accuracy: 0.9200 - 6s/epoch - 574ms/step
# Epoch 26/100
# 10/10 - 6s - loss: 0.1216 - accuracy: 0.9233 - val_loss: 0.2696 - val_accuracy: 0.9200 - 6s/epoch - 587ms/step
# Epoch 27/100
# 10/10 - 6s - loss: 0.1143 - accuracy: 0.9433 - val_loss: 0.2966 - val_accuracy: 0.9133 - 6s/epoch - 592ms/step
# Epoch 28/100
# 10/10 - 6s - loss: 0.1204 - accuracy: 0.9250 - val_loss: 0.2742 - val_accuracy: 0.9467 - 6s/epoch - 633ms/step
# Epoch 29/100
# 10/10 - 6s - loss: 0.1154 - accuracy: 0.9383 - val_loss: 0.2900 - val_accuracy: 0.9333 - 6s/epoch - 610ms/step
# Epoch 30/100
# 10/10 - 6s - loss: 0.1177 - accuracy: 0.9333 - val_loss: 0.2016 - val_accuracy: 0.9467 - 6s/epoch - 571ms/step
# Epoch 31/100
# 10/10 - 6s - loss: 0.1037 - accuracy: 0.9467 - val_loss: 0.2364 - val_accuracy: 0.9267 - 6s/epoch - 644ms/step
# Epoch 32/100
# 10/10 - 6s - loss: 0.1197 - accuracy: 0.9267 - val_loss: 0.1835 - val_accuracy: 0.9400 - 6s/epoch - 626ms/step
# Epoch 33/100
# 10/10 - 7s - loss: 0.1008 - accuracy: 0.9550 - val_loss: 0.2620 - val_accuracy: 0.8733 - 7s/epoch - 713ms/step
# Epoch 34/100
# 10/10 - 6s - loss: 0.0964 - accuracy: 0.9483 - val_loss: 0.2633 - val_accuracy: 0.8800 - 6s/epoch - 573ms/step
# Epoch 35/100
# 10/10 - 6s - loss: 0.0835 - accuracy: 0.9617 - val_loss: 0.1390 - val_accuracy: 0.9467 - 6s/epoch - 619ms/step
# Epoch 36/100
# 10/10 - 6s - loss: 0.1183 - accuracy: 0.9433 - val_loss: 0.2848 - val_accuracy: 0.9400 - 6s/epoch - 574ms/step
# Epoch 37/100
# 10/10 - 6s - loss: 0.0893 - accuracy: 0.9550 - val_loss: 0.1840 - val_accuracy: 0.9400 - 6s/epoch - 599ms/step
# Epoch 38/100
# 10/10 - 6s - loss: 0.0760 - accuracy: 0.9517 - val_loss: 0.2036 - val_accuracy: 0.9400 - 6s/epoch - 635ms/step
# Epoch 39/100
# 10/10 - 7s - loss: 0.0848 - accuracy: 0.9583 - val_loss: 0.1742 - val_accuracy: 0.9400 - 7s/epoch - 655ms/step
# Epoch 40/100
# 10/10 - 6s - loss: 0.0812 - accuracy: 0.9533 - val_loss: 0.2131 - val_accuracy: 0.9400 - 6s/epoch - 592ms/step
# Epoch 41/100
# 10/10 - 7s - loss: 0.0936 - accuracy: 0.9450 - val_loss: 0.1840 - val_accuracy: 0.9400 - 7s/epoch - 695ms/step
# Epoch 42/100
# 10/10 - 6s - loss: 0.0712 - accuracy: 0.9600 - val_loss: 0.1793 - val_accuracy: 0.9400 - 6s/epoch - 628ms/step
# Epoch 43/100
# 10/10 - 7s - loss: 0.0916 - accuracy: 0.9417 - val_loss: 0.1570 - val_accuracy: 0.9533 - 7s/epoch - 654ms/step
# Epoch 44/100
# 10/10 - 6s - loss: 0.0699 - accuracy: 0.9633 - val_loss: 0.1295 - val_accuracy: 0.9400 - 6s/epoch - 616ms/step
# Epoch 45/100
# 10/10 - 7s - loss: 0.0835 - accuracy: 0.9367 - val_loss: 0.1611 - val_accuracy: 0.9467 - 7s/epoch - 691ms/step
# Epoch 46/100
# 10/10 - 6s - loss: 0.0887 - accuracy: 0.9600 - val_loss: 0.1525 - val_accuracy: 0.9400 - 6s/epoch - 620ms/step
# Epoch 47/100
# 10/10 - 7s - loss: 0.0900 - accuracy: 0.9550 - val_loss: 0.1419 - val_accuracy: 0.9400 - 7s/epoch - 659ms/step
# Epoch 48/100
# 10/10 - 7s - loss: 0.0689 - accuracy: 0.9583 - val_loss: 0.1871 - val_accuracy: 0.9267 - 7s/epoch - 672ms/step
# Epoch 49/100
# 10/10 - 7s - loss: 0.0913 - accuracy: 0.9533 - val_loss: 0.1316 - val_accuracy: 0.9467 - 7s/epoch - 730ms/step
# Epoch 50/100
# 10/10 - 6s - loss: 0.0816 - accuracy: 0.9483 - val_loss: 0.1672 - val_accuracy: 0.9400 - 6s/epoch - 588ms/step
# Epoch 51/100
# 10/10 - 6s - loss: 0.0690 - accuracy: 0.9567 - val_loss: 0.1333 - val_accuracy: 0.9533 - 6s/epoch - 599ms/step
# Epoch 52/100
# 10/10 - 7s - loss: 0.0722 - accuracy: 0.9567 - val_loss: 0.1314 - val_accuracy: 0.9533 - 7s/epoch - 708ms/step
# Epoch 53/100
# 10/10 - 7s - loss: 0.0636 - accuracy: 0.9617 - val_loss: 0.1278 - val_accuracy: 0.9533 - 7s/epoch - 721ms/step
# Epoch 54/100
# 10/10 - 6s - loss: 0.0689 - accuracy: 0.9667 - val_loss: 0.1311 - val_accuracy: 0.9467 - 6s/epoch - 594ms/step
# Epoch 55/100
# 10/10 - 6s - loss: 0.0895 - accuracy: 0.9450 - val_loss: 0.1359 - val_accuracy: 0.9467 - 6s/epoch - 570ms/step
# Epoch 56/100
# 10/10 - 6s - loss: 0.0688 - accuracy: 0.9533 - val_loss: 0.1227 - val_accuracy: 0.9467 - 6s/epoch - 580ms/step
# Epoch 57/100
# 10/10 - 6s - loss: 0.0751 - accuracy: 0.9533 - val_loss: 0.1629 - val_accuracy: 0.9400 - 6s/epoch - 607ms/step
# Epoch 58/100
# 10/10 - 7s - loss: 0.0860 - accuracy: 0.9433 - val_loss: 0.1145 - val_accuracy: 0.9467 - 7s/epoch - 657ms/step
# Epoch 59/100
# 10/10 - 6s - loss: 0.0825 - accuracy: 0.9517 - val_loss: 0.2194 - val_accuracy: 0.9067 - 6s/epoch - 606ms/step
# Epoch 60/100
# 10/10 - 6s - loss: 0.0753 - accuracy: 0.9600 - val_loss: 0.2070 - val_accuracy: 0.9200 - 6s/epoch - 639ms/step
# Epoch 61/100
# 10/10 - 7s - loss: 0.0846 - accuracy: 0.9467 - val_loss: 0.2623 - val_accuracy: 0.9200 - 7s/epoch - 651ms/step
# Epoch 62/100
# 10/10 - 6s - loss: 0.0789 - accuracy: 0.9500 - val_loss: 0.1616 - val_accuracy: 0.9400 - 6s/epoch - 642ms/step
# Epoch 63/100
# 10/10 - 6s - loss: 0.0822 - accuracy: 0.9567 - val_loss: 0.1680 - val_accuracy: 0.9267 - 6s/epoch - 640ms/step
# Epoch 64/100
# 10/10 - 7s - loss: 0.0882 - accuracy: 0.9367 - val_loss: 0.1346 - val_accuracy: 0.9533 - 7s/epoch - 672ms/step
# Epoch 65/100
# 10/10 - 7s - loss: 0.0878 - accuracy: 0.9300 - val_loss: 0.1318 - val_accuracy: 0.9467 - 7s/epoch - 651ms/step
# Epoch 66/100
# 10/10 - 7s - loss: 0.0760 - accuracy: 0.9467 - val_loss: 0.1441 - val_accuracy: 0.9467 - 7s/epoch - 650ms/step
# Epoch 67/100
# 10/10 - 6s - loss: 0.0726 - accuracy: 0.9467 - val_loss: 0.1382 - val_accuracy: 0.9467 - 6s/epoch - 636ms/step
# Epoch 68/100
# 10/10 - 6s - loss: 0.0670 - accuracy: 0.9517 - val_loss: 0.1013 - val_accuracy: 0.9533 - 6s/epoch - 599ms/step
# Epoch 69/100
# 10/10 - 6s - loss: 0.0641 - accuracy: 0.9483 - val_loss: 0.1329 - val_accuracy: 0.9400 - 6s/epoch - 639ms/step
# Epoch 70/100
# 10/10 - 7s - loss: 0.0648 - accuracy: 0.9533 - val_loss: 0.1106 - val_accuracy: 0.9533 - 7s/epoch - 670ms/step
# Epoch 71/100
# 10/10 - 6s - loss: 0.0701 - accuracy: 0.9483 - val_loss: 0.1215 - val_accuracy: 0.9533 - 6s/epoch - 588ms/step
# Epoch 72/100
# 10/10 - 6s - loss: 0.0660 - accuracy: 0.9500 - val_loss: 0.1480 - val_accuracy: 0.9467 - 6s/epoch - 606ms/step
# Epoch 73/100
# 10/10 - 7s - loss: 0.0622 - accuracy: 0.9550 - val_loss: 0.1521 - val_accuracy: 0.9400 - 7s/epoch - 689ms/step
# Epoch 74/100
# 10/10 - 8s - loss: 0.0670 - accuracy: 0.9483 - val_loss: 0.1202 - val_accuracy: 0.9533 - 8s/epoch - 756ms/step
# Epoch 75/100
# 10/10 - 6s - loss: 0.0574 - accuracy: 0.9600 - val_loss: 0.1557 - val_accuracy: 0.9467 - 6s/epoch - 589ms/step
# Epoch 76/100
# 10/10 - 6s - loss: 0.0615 - accuracy: 0.9483 - val_loss: 0.1275 - val_accuracy: 0.9533 - 6s/epoch - 611ms/step
# Epoch 77/100
# 10/10 - 6s - loss: 0.0628 - accuracy: 0.9650 - val_loss: 0.1168 - val_accuracy: 0.9533 - 6s/epoch - 615ms/step
# Epoch 78/100
# 10/10 - 6s - loss: 0.0645 - accuracy: 0.9500 - val_loss: 0.1587 - val_accuracy: 0.9467 - 6s/epoch - 646ms/step
# Epoch 79/100
# 10/10 - 6s - loss: 0.0670 - accuracy: 0.9567 - val_loss: 0.1429 - val_accuracy: 0.9533 - 6s/epoch - 609ms/step
# Epoch 80/100
# 10/10 - 6s - loss: 0.0718 - accuracy: 0.9517 - val_loss: 0.1611 - val_accuracy: 0.9467 - 6s/epoch - 611ms/step
# Epoch 81/100
# 10/10 - 6s - loss: 0.0666 - accuracy: 0.9500 - val_loss: 0.1622 - val_accuracy: 0.9467 - 6s/epoch - 605ms/step
# Epoch 82/100
# 10/10 - 6s - loss: 0.0726 - accuracy: 0.9550 - val_loss: 0.1524 - val_accuracy: 0.9600 - 6s/epoch - 598ms/step
# Epoch 83/100
# 10/10 - 7s - loss: 0.0605 - accuracy: 0.9550 - val_loss: 0.1846 - val_accuracy: 0.9467 - 7s/epoch - 723ms/step
# Epoch 84/100
# 10/10 - 7s - loss: 0.0603 - accuracy: 0.9533 - val_loss: 0.1938 - val_accuracy: 0.9333 - 7s/epoch - 661ms/step
# Epoch 85/100
# 10/10 - 7s - loss: 0.0739 - accuracy: 0.9450 - val_loss: 0.2266 - val_accuracy: 0.9267 - 7s/epoch - 657ms/step
# Epoch 86/100
# 10/10 - 6s - loss: 0.0747 - accuracy: 0.9400 - val_loss: 0.2059 - val_accuracy: 0.9600 - 6s/epoch - 629ms/step
# Epoch 87/100
# 10/10 - 6s - loss: 0.0608 - accuracy: 0.9500 - val_loss: 0.1803 - val_accuracy: 0.9533 - 6s/epoch - 633ms/step
# Epoch 88/100
# 10/10 - 6s - loss: 0.0646 - accuracy: 0.9550 - val_loss: 0.1647 - val_accuracy: 0.9467 - 6s/epoch - 630ms/step
# Epoch 89/100
# 10/10 - 6s - loss: 0.0672 - accuracy: 0.9483 - val_loss: 0.1477 - val_accuracy: 0.9467 - 6s/epoch - 640ms/step
# Epoch 90/100
# 10/10 - 6s - loss: 0.0553 - accuracy: 0.9617 - val_loss: 0.1800 - val_accuracy: 0.9533 - 6s/epoch - 627ms/step
# Epoch 91/100
# 10/10 - 7s - loss: 0.0564 - accuracy: 0.9667 - val_loss: 0.2114 - val_accuracy: 0.9333 - 7s/epoch - 651ms/step
# Epoch 92/100
# 10/10 - 6s - loss: 0.0704 - accuracy: 0.9650 - val_loss: 0.2179 - val_accuracy: 0.9533 - 6s/epoch - 649ms/step
# Epoch 93/100
# 10/10 - 6s - loss: 0.0674 - accuracy: 0.9583 - val_loss: 0.2158 - val_accuracy: 0.9533 - 6s/epoch - 638ms/step
# Epoch 94/100
# 10/10 - 7s - loss: 0.0810 - accuracy: 0.9483 - val_loss: 0.1598 - val_accuracy: 0.9533 - 7s/epoch - 677ms/step
# Epoch 95/100
# 10/10 - 10s - loss: 0.0725 - accuracy: 0.9483 - val_loss: 0.2260 - val_accuracy: 0.9200 - 10s/epoch - 1s/step
# Epoch 96/100
# 10/10 - 7s - loss: 0.0576 - accuracy: 0.9700 - val_loss: 0.3199 - val_accuracy: 0.9000 - 7s/epoch - 657ms/step
# Epoch 97/100
# 10/10 - 7s - loss: 0.0601 - accuracy: 0.9600 - val_loss: 0.1933 - val_accuracy: 0.9133 - 7s/epoch - 682ms/step
# Epoch 98/100
# 10/10 - 7s - loss: 0.0626 - accuracy: 0.9583 - val_loss: 0.2177 - val_accuracy: 0.9133 - 7s/epoch - 661ms/step
# Epoch 99/100
# 10/10 - 6s - loss: 0.0578 - accuracy: 0.9717 - val_loss: 0.2827 - val_accuracy: 0.9533 - 6s/epoch - 648ms/step
# Epoch 100/100
# 10/10 - 7s - loss: 0.0623 - accuracy: 0.9600 - val_loss: 0.2015 - val_accuracy: 0.9467 - 7s/epoch - 688ms/step

# %%
#happy_model.evaluate(X_test, y_test)

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.plot(acc, label = "Training Accuracy")
plt.plot(val_acc, label = "Validation Accuracy")
plt.legend(loc = 'lower right')
plt.title("Training and Validation accuracy")
plt.show()

# %%
plt.plot(loss, label = "Training loss")
plt.plot(val_loss, label = "Validation loss")
plt.legend(loc = 'upper right')
plt.title("Training and Validation Loss")
plt.show()
